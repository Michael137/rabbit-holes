# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
int8_data = pd.read_csv('int8.csv')
int32_data = pd.read_csv('int32.csv')
float_data = pd.read_csv('float.csv')

# %%
int8_data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x23fa5d850>]],
#       dtype=object)

# %%
int32_data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x18538add0>]],
#       dtype=object)

# %%
float_data.hist(bins=10000)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x185484f50>]],
#       dtype=object)
