# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
int8_data = pd.read_csv('int8.csv')
int32_data = pd.read_csv('int32.csv')
float_data = pd.read_csv('float.csv')

# %%
int8_data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10bcca550>]],
#       dtype=object)

# %%
int32_data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x120a88090>]],
#       dtype=object)

# %%
float_data.hist(bins=10000)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x120a71590>]],
#       dtype=object)
